# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.patches as patches

import glob
import os
import logging
import datetime
import warnings
import re
import sys 
from skimage import io

from copy import deepcopy
from lmfit.models import GaussianModel, LorentzianModel

# from matplotlib.colors import Normalize
from scipy.optimize import curve_fit

plt.rcParams['xtick.major.width'] = 1.8
plt.rcParams['axes.edgecolor'] = 'k'
plt.rcParams['errorbar.capsize'] = 5
plt.rcParams['lines.markersize'] = 4.
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
def power_run_analysis(path, roi, filebg = None, flag_plot=False):
    files = glob.glob(path)
    files.sort()

    if filebg != None:
        imdark = io.imread(filebg).astype(np.int64)

    avInt = []
    unInt = []
    pows = []

    for f in files:
        name = os.path.split(f)[1]
        power = float(re.search(r'([-+]?\d\.\d+e[-+]?\d+)', name).group(1))
        pows.append(power)
        
        img = io.imread(f).astype(np.int64)
        if filebg != None:
            img -= imdark                            #  Live subtract imdark (filter 2)
        imroi = img[roi[0]:roi[1], roi[2]:roi[3]]
        intPx = img.sum()/roiSize
        avInt.append(intPx)
        
        unPx = np.sqrt((imroi**2).sum()) / roiSize
        unInt.append(unPx)
    
    if flag_plot:
        plt.errorbar(x=pows, y=avInt, yerr=unPx, fmt='o')
        plt.gca().set(xlabel='Power (W)', ylabel='Counts/px')

    dfres = pd.DataFrame({'power': pows, 'counts': avInt, 'dcounts': unInt})

    return dfres

# %% [markdown]
# # Set ROI

# %%
roi = [400, 1300, 400, 1300]
rootpath = '/Users/pabloherrero/Library/CloudStorage/GoogleDrive-qmlab@mail.huji.ac.il/My Drive/Ba Tagging/data/img/singles/19-01-25/'
filebg = '/Users/pabloherrero/Library/CloudStorage/GoogleDrive-qmlab@mail.huji.ac.il/My Drive/Ba Tagging/data/img/sets/19-01-25/Rhodamine-B 50 µM/1/Dark_Blind_17-09-40.tif'

# %%
filetest = '/Users/pabloherrero/Library/CloudStorage/GoogleDrive-qmlab@mail.huji.ac.il/My Drive/Ba Tagging/data/img/singles/19-01-25/Rhodamine-B 50 µM/10/Center-586nm_Width-26nm_2.71254648e-05uW_17-31-21.tif'
img = io.imread(filetest).astype(np.int64)
imroi = img[roi[0]:roi[1], roi[2]:roi[3]]
roiSize = imroi.shape[0] * imroi.shape[1]
plt.imshow(img, clim=(3.4e4, 3.6e4), origin='upper')
square = patches.Rectangle((roi[0], roi[2]), roi[1]-roi[0], roi[3]-roi[2], edgecolor='red', facecolor='none', linewidth=2)
plt.gca().add_patch(square)
plt.colorbar()

# %% [markdown]
# # Calibration: Rhodamine-B 50 µM with TOptica laser

# %%
prhod = rootpath + 'Rhodamine-B 50 µM/**/*.tif'
dfrhod = power_run_analysis(prhod, roi, filebg=filebg, flag_plot=True)
plt.gca().set(title='Rhodamine-B 50 µM')
# Out:
# [Text(0.5, 1.0, 'Rhodamine-B 50 µM')]

# %% [markdown]
# # Quartz, TOptica and diode lasers

# %%
p_top = rootpath + 'quartz_toptica' +'/**/*.tif'
dftop = power_run_analysis(p_top, roi, filebg=filebg)

p_dd = rootpath + 'quartz_diode' +'/**/*.tif'
dfdd = power_run_analysis(p_dd, roi, filebg=filebg)

dfdd['power'] = dfdd['power'].sort_values().reset_index(drop=True)
dfdd['power'] = dfdd['power'].apply(lambda x: x/1e-6)

dftop['power'] = dftop['power'].sort_values().reset_index(drop=True)
dftop['power'] = dftop['power'].apply(lambda x: x/1e-6)

# %%
plt.errorbar(x=dftop.power, y=dftop.counts, yerr=dftop.dcounts, fmt='o', label='TOptica')
plt.errorbar(x=dfdd.power, y=dfdd.counts, yerr=dfdd.dcounts, fmt='o', label='Diode')
plt.legend()
plt.gca().set(title='Quartz reflection', xlabel='Power (µW)', ylabel='Counts/px')
# Out:
# [Text(0, 0.5, 'Counts/px'),
#  Text(0.5, 0, 'Power (µW)'),
#  Text(0.5, 1.0, 'Quartz reflection')]

# %%
path = r'G:\My Drive\Ba Tagging\data\img\time\04-02-25\Rhodamine-B 50 µM\Hokawo-1\Rhodamine B 50uM 500ms 28 uW, no bgsub - Field 05.tif'
timev = io.imread(path)

# %%
plt.imshow(timev[0])
plt.colorbar()

# %%
plt.plot(timev[:,1200, 700])
plt.gca().set(xlabel='Frame (nr.)', ylabel='Counts', title='Pixel (1250, 750)')
# Out:
# [Text(0.5, 0, 'Frame (nr.)'),
#  Text(0, 0.5, 'Counts'),
#  Text(0.5, 1.0, 'Pixel (1250, 750)')]

# %%
plt.plot(timev[:,1000, 1000])
plt.gca().set(xlabel='Frame (nr.)', ylabel='Counts', title='Pixel (1250, 750)')
# Out:
# [Text(0.5, 0, 'Frame (nr.)'),
#  Text(0, 0.5, 'Counts'),
#  Text(0.5, 1.0, 'Pixel (1250, 750)')]

# %%
path2 = r'G:\My Drive\Ba Tagging\data\img\time\04-02-25\Rhodamine-B 50 µM\1\*.tif'
timev2 = np.zeros_like(timev)
files = glob.glob(path2)
files.sort()

timev2[:] = [io.imread(f) for f in files]

# %%
plt.imshow(timev2[0])
plt.colorbar()

# %%
plt.plot(timev2[:,1000, 1000])
plt.gca().set(xlabel='Frame (nr.)', ylabel='Counts', title='Pixel (1000, 1000)')
# Out:
# [Text(0.5, 0, 'Frame (nr.)'),
#  Text(0, 0.5, 'Counts'),
#  Text(0.5, 1.0, 'Pixel (1000, 1000)')]
